# %% [markdown]
# ![Caratula](https://total10fashion.com/wp-content/uploads/2022/07/Sustainable-Fashion-Ideas-768x430.png)

# %% [markdown]
# # La percepción del impacto de la Moda sobre el planeta

# %% [markdown]
# ### TEMA

# %% [markdown]
# La percepción del consumidor sobre impacto de la industria de la moda en medio ambiente y qué están haciendo las marcas por ser más sostenibles y éticas.
#
# A través de cifras sobre emisiones, contaminación, uso de los recursos; teniendo en cuenta el tipo de moda que fabrican (fast-non trend, fast-trend y ultrafast), el múmero de colecciones, volumen de prendas e ingresos; ¿cómo percibe el consumidor a esas marcas?

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# ·*Hipótesis 1*: ¿Existe una relación entre las reacciones en redes sociales con la forma de producción de una marca de moda?
#
# ·*Hipótesis 2* = ¿Cuanto más fast es una marca más contamina?
#
# ·*Hipótesis 3* = ¿Cómo está evolucionando la industria de la moda en términos de sostenibilidad e ingresos?
#
# ·*Hipótesis* 4 = ¿La percepción que tiene la gente sobre si una marca es 'verde' es reflejo de la realidad?

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
df_1 = pd.read_csv(r"C:\Users\isabe\Documents\Thebridge\Descargas documentos\Fashion-EDA\Datasets\true_cost_fast_fashion.csv")
fuente_1 = "https://www.kaggle.com/datasets/khushikyad001/the-true-cost-of-fast-fashion-impact"
df_2 = pd.read_csv(r"C:\Users\isabe\Documents\Thebridge\Descargas documentos\Fashion-EDA\Datasets\Plastic based Textiles in clothing industry.csv")
fuente_2 = "https://www.kaggle.com/datasets/purohitgaurav/plastic-based-textiles-in-clothing-industry"

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
#True Cost of Fashion
df_1.head()
# Out:
#         Brand    Country  Year  Monthly_Production_Tonnes  Avg_Item_Price_USD  \
# 0       Shein  Indonesia  2017                     574.51               19.31
# 1  Forever 21    Vietnam  2024                     394.50                9.30
# 2      Uniqlo      India  2024                     310.23               25.46
# 3  Forever 21        USA  2017                     218.65               13.17
# 4        Zara  Indonesia  2016                    1005.84               15.40
#
#    Release_Cycles_Per_Year  Carbon_Emissions_tCO2e  \
# 0                       16                11421.58
# 1                       20                 5571.01
# 2                       11                10969.00
# 3                       13                13093.00
# 4                       20                 9548.40
#
#    Water_Usage_Million_Litres  Landfill_Waste_Tonnes  Avg_Worker_Wage_USD  \
# 0                      282.11                 616.63               143.79
# ...

# %%
# Cifras por tipo de fibra
df_2.head()
# Out:
#   Company     Product_Type  Production_Year  Greenhouse_Gas_Emissions  \
# 0    Zara        Polyester             2020                      5000
# 1    Zara            Nylon             2019                      3000
# 2    Zara    Recycled_Poly             2021                      3500
# 3    Zara           Cotton             2018                      2000
# 4    Zara  Synthetic_Blend             2022                      6000
#
#    Pollutants_Emitted  Water_Consumption  Energy_Consumption  \
# 0                  20               7500                1200
# 1                  15               5000                 900
# 2                  18               6000                1100
# 3                  10               4500                 800
# 4                  25               8000                1500
#
#    Waste_Generation  Sales_Revenue
# 0               300         500000
# 1               200         450000
# 2               250         480000
# ...

# %%
print(df_1.info())
print('***********************************************************************')
print(df_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Brand                         3000 non-null   object
#  1   Country                       3000 non-null   object
#  2   Year                          3000 non-null   int64
#  3   Monthly_Production_Tonnes     3000 non-null   float64
#  4   Avg_Item_Price_USD            3000 non-null   float64
#  5   Release_Cycles_Per_Year       3000 non-null   int64
#  6   Carbon_Emissions_tCO2e        3000 non-null   float64
#  7   Water_Usage_Million_Litres    3000 non-null   float64
#  8   Landfill_Waste_Tonnes         3000 non-null   float64
#  9   Avg_Worker_Wage_USD           3000 non-null   float64
#  10  Working_Hours_Per_Week        3000 non-null   int64
#  11  Child_Labor_Incidents         3000 non-null   int64
# ...
